# %%
import pandas as pd

# %%
dataset = pd.read_csv("../input/processed/customer_churn.csv")

# %%
dataset.head()
# Out:
#    SeniorCitizen  Partner  Dependents  tenure  PhoneService  PaperlessBilling  \
# 0              0        0           0      27             1                 1
# 1              0        0           0       6             0                 1
# 2              0        1           1      29             1                 0
# 3              0        0           0       1             1                 0
# 4              0        1           1       8             1                 0
#
#    MonthlyCharges  TotalCharges  target  InternetService_DSL  ...  \
# 0           19.60        561.15       0                    0  ...
# 1           63.40        348.80       0                    1  ...
# 2           75.55       2054.40       0                    1  ...
# 3           18.85         18.85       0                    0  ...
# 4           55.75        446.80       0                    1  ...
#
#    StreamingTV_Nointernetservice  StreamingTV_Yes  StreamingMovies_No  \
# ...

# %%
dataset.describe()
# Out:
#        SeniorCitizen      Partner   Dependents       tenure  PhoneService  \
# count    7043.000000  7043.000000  7043.000000  7043.000000   7043.000000
# mean        0.162147     0.483033     0.299588    32.371149      0.903166
# std         0.368612     0.499748     0.458110    24.559481      0.295752
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     9.000000      1.000000
# 50%         0.000000     0.000000     0.000000    29.000000      1.000000
# 75%         0.000000     1.000000     1.000000    55.000000      1.000000
# max         1.000000     1.000000     1.000000    72.000000      1.000000
#
#        PaperlessBilling  MonthlyCharges  TotalCharges       target  \
# count       7043.000000     7043.000000   7043.000000  7043.000000
# mean           0.592219       64.761692   2279.734304     0.265370
# std            0.491457       30.090047   2266.794470     0.441561
# ...

# %% [markdown]
# Check for null values in any of the columns. Also get a look at the dtypes of those columns

# %%
for col in dataset.columns:
    print(pd.isnull(dataset[col]).value_counts())

# %% [markdown]
# Handy functionality, let's look for the different value counts of the raw values in each column to get an idea of what will have to be encoded

# %%
for col in dataset.columns:
    print(dataset[col].value_counts())
    print()

# %% [markdown]
# # Actions

# %% [markdown]
# ## Drop
# - customerId
#
# ## Map to Bool
# - Male/Female (rename col)
# - Partner
# - Dependents
# - PhoneService
# - PaperlessBilling
#
# ## Map to Categorical
# - InternetService
# - Contract
# - PaymentMethod
# - OnlineSecurity
# - OnlineBackup
# - DeviceProtection
# - TechSupport
# - StreamingTV
# - StreamingMovies
# - MultipleLines

# %% [markdown]
# # Try One Hot Encoding

# %%
from sklearn import preprocessing

# %%
ohe = preprocessing.OneHotEncoder(sparse=False)

# %%
example = ohe.fit_transform(dataset["InternetService"].values.reshape(-1, 1))

# %%
dataset["TechSupport"] = example

# %%
example.shape

# %%
example
